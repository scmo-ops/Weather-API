# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Setting up the url

url = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'metric'
query_url = f'{url}appid={weather_api_key}&units={units}&q='


# Lists for the data frame of the next step and import datetime to have a readable date


city_id = []
city_name = []
city_lat = []
city_lng = []
city_max_temp = []
city_humidity = []
city_cloudiness = []
city_wind_speed = []
city_country = []
city_date = []

# Loop through cities

print('Beginning Data Retrieval')
print('-----------------------------')

for city in cities:
    # Get the Json response from the OpenWeather API
    response_json = requests.get(query_url + city).json()

    # Retrieve the items for each field and append them to the empty lists  
    try:
        
        city_id1 = response_json['id']
        city_id.append(city_id1)
            
        city_name1 = response_json['name']
        city_name.append(city_name1)
        
        city_lat1 = response_json['coord']['lat']
        city_lat.append(city_lat1)
        
        city_lng1 = response_json['coord']['lon']
        city_lng.append(city_lng1)
        
        city_max_temp1 = response_json['main']['temp']
        city_max_temp.append(city_max_temp1)
        
        city_humidity1 = response_json['main']['humidity']
        city_humidity.append(city_humidity1)
        
        city_cloudiness1 = response_json['clouds']['all']
        city_cloudiness.append(city_cloudiness1)
        
        city_wind_speed1 = response_json['wind']['speed']
        city_wind_speed.append(city_wind_speed1)
        
        city_country1 = response_json['sys']['country']
        city_country.append(city_country1)
        
        ts = int(response_json['dt'])
        city_date1= datetime.utcfromtimestamp(ts).strftime('%Y-%m-%d %H:%M:%S')
        city_date.append(city_date1)
        
        print(f'Processing Record | {city_name}')
    
    # Error message if the city id is not found
    except:
        
        print('City not found. Skipping...')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record | ['Saint Paul Harbor']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp']
# City not found. Skipping...
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk"]
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux']
# City not found. Skipping...
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur']
# City not found. Skipping...
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka']
# City not found. Skipping...
# City not found. Skipping...
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow']
# City not found. Skipping...
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye']
# City not found. Skipping...
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan']
# City not found. Skipping...
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu', 'Sawankhalok']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu', 'Sawankhalok', 'Jamestown']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu', 'Sawankhalok', 'Jamestown', 'Vaini']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu', 'Sawankhalok', 'Jamestown', 'Vaini', 'Provideniya']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu', 'Sawankhalok', 'Jamestown', 'Vaini', 'Provideniya', 'Cap Malheureux']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu', 'Sawankhalok', 'Jamestown', 'Vaini', 'Provideniya', 'Cap Malheureux', 'Pisco']
# City not found. Skipping...
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu', 'Sawankhalok', 'Jamestown', 'Vaini', 'Provideniya', 'Cap Malheureux', 'Pisco', 'Broken Hill']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu', 'Sawankhalok', 'Jamestown', 'Vaini', 'Provideniya', 'Cap Malheureux', 'Pisco', 'Broken Hill', 'Karratha']
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatanga', 'Acajutla', 'Bathsheba', 'Kaitangata', 'Pacific Grove', 'Avarua', 'George Town', 'Province of Vibo Valentia', 'Port Elizabeth', 'Sinnamary', 'Kotka', 'Hithadhoo', 'Geraldton', 'Atuona', 'Barrow', 'Airai', 'Saskylakh', 'Ponta do Sol', 'Nikolskoye', 'Grande Prairie', 'Hermanus', 'Sept-Îles', 'Mataura', 'Thomaston', 'Tasiilaq', 'Kargasok', 'Dikson', 'Mehamn', 'La Ronge', 'New Norfolk', 'Ketchikan', 'Rikitea', 'Vila Franca do Campo', 'Palu', 'Sawankhalok', 'Jamestown', 'Vaini', 'Provideniya', 'Cap Malheureux', 'Pisco', 'Broken Hill', 'Karratha', 'Guozhen']
# ...
# Processing Record | ['Saint Paul Harbor', 'Fukuechō', 'Nanortalik', 'Meadow Lake', 'Punta Arenas', 'Leh', 'Busselton', 'Saint Andrews', 'Ridgecrest', 'Carnarvon', 'Yulara', 'Cidreira', 'Repalle', 'Souillac', 'Elkhart', 'Cayenne', 'Ushuaia', 'Upernavik', 'Kahului', 'Stornoway', 'Paamiut', 'Bredasdorp', 'Puerto Ayora', 'Itarema', "Severo-Kuril'sk", 'Hobart', 'Boiro', 'Bambous Virieux', 'Tuktoyaktuk', 'Qaanaaq', 'Saint-Augustin', 'Ise', 'Kiknur', 'Cherskiy', 'Hong Kong', 'Ürümqi', 'Sobradinho', 'Albany', 'Simbahan', 'Kapaa', 'Khatan
oln', 'Muros', 'Belyy Yar', 'Hervey Bay', 'Huarmey', 'Chokurdakh', 'Sibu', 'Port Alfred', 'Vila Velha', 'Olafsvik', 'Teahupoo', 'Haimen', 'Butaritari', 'Gizo Government Station', 'Matara', 'Pilot Butte', 'Esperance', 'Laguna', 'Marsá Maţrūḩ', 'Salalah', 'Ampanihy', 'Pangkalanbuun', 'Rawson', 'Ancud', 'Nelson Bay', 'Valle de Allende', 'Bluff', 'Mossendjo', 'Menongue', 'Tuy Hoa', 'Jonesboro', 'La Asuncion', 'Kasongo-Lunda', 'Kenora', 'Ranau', 'Strezhevoy', 'Havelock', 'Soe', 'Lagoa', 'Sumenep', 'Aginskoye', 'Whitehaven', 'Bayir', 'Saint-Philippe', 'Arraial do Cabo', 'Lüderitz', 'Mendeleyevo', 'Hasaki', "Ust'-Kut", 'Turukhansk', 'Isla Vista', 'Erdenet', 'Libreville', 'Kruisfontein', 'Monrovia', 'Saint George', 'Sovkhoznyy', 'Mocuba', 'Chui', 'Mbandaka', 'Praia', 'Havre-St-Pierre', 'Am Timan', 'Beloha', 'Iqaluit', 'Waitara', 'Mana', 'Abbeville', 'Ode', 'Quatre Cocos', 'Bilibino', 'Sola', 'Birūr', 'Yangi Marg`ilon', 'Salamanca', 'Padang', 'Palimbang', 'Kununurra', 'Aasiaat', 'Grand Gaube', 'Ngunguru', 'São Filipe', 'Kumul', 'Roald', 'Okhotsk', 'Coyhaique', 'Port Augusta', 'Clyde River', 'Portland', 'Anadyr', 'Vicuña', 'Vinukonda', 'Terrace', 'Mandalgovi', 'Mandello del Lario', 'Begamganj', 'Aripuanã', 'Henties Bay', 'San Patricio', 'Sibut', 'Mubende', 'Voinka', 'Aleksandrov Gay', 'Visby', 'Modugno', 'Loikaw', 'Touros', 'Vestmannaeyjar', 'Porto Franco', 'Mfou', 'San Cristobal', 'Praia da Vitória', 'Alagir', 'Kudahuvadhoo', 'Puerto El Triunfo', 'Broome', 'Dzerzhinskoye', 'Vung Tau', 'Goderich', 'Charagua', 'Alofi', 'Novo Mesto', 'Mossamedes', 'Belmonte', 'Dawlatabad ...
# City not found. Skipping...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Data Frame
city_df = pd.DataFrame({'ID': city_id, 'City': city_name, 'Lat': city_lat, 'Lng': city_lng, 'Max Temp': city_max_temp, 'Humidity': city_humidity, 'Cloudiness': city_cloudiness, 'Wind Speed': city_wind_speed, 'Country': city_country, 'Date': city_date})
city_df.head()
# Out:
#         ID               City      Lat       Lng  Max Temp  Humidity  \
# 0  5866583  Saint Paul Harbor  57.7900 -152.4072      7.00        81
# 1  1863997           Fukuechō  32.6881  128.8419     23.00        28
# 2  3421765         Nanortalik  60.1432  -45.2371      2.52        84
# 3  5478673        Meadow Lake  34.8014 -106.5436     13.17        25
# 4  3874787       Punta Arenas -53.1500  -70.9167      5.77        93
#
#    Cloudiness  Wind Speed Country                 Date
# 0          90        1.24      US  2021-04-30 04:27:21
# 1           0        6.69      JP  2021-04-30 04:27:21
# 2          11        3.59      GL  2021-04-30 04:27:22
# 3           1        3.60      US  2021-04-30 04:27:22
# 4          90        2.57      CL  2021-04-30 04:24:40

# %%
city_df.to_csv('../output_data/cities.csv', index = False, header = True)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

city_df.index[city_df['Humidity'] > 100].tolist()
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

#since the current data set does not contain a city where the Humidity goes over
# 100%, im skipping this step

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Set x an y axis values to graph

x_axis = city_df['Lat']
y_axis = city_df['Max Temp']

# Using matplotlib to get and save the graph

plt.scatter(x_axis, y_axis)
plt.title('City Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.xlim(-60, 80)
plt.ylim(-20, 100)
plt.minorticks_on()
plt.grid()
#plt.tight_layout()
plt.show()
plt.savefig('../output_data/Fig1.png')


# This is to analyze the relationship between the latitude of the cities and the temperature of them,
# as we can see, it gets hotter as it approches the equator and colder as it approches the poles.
# So, there is a significant relationship between these two parameters.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Set x an y axis values to graph

x_axis1 = city_df['Lat']
y_axis1 = city_df['Humidity']

# Using matplotlib to get and save the graph

plt.scatter(x_axis1, y_axis1)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.ylim(-20, 120)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid()

plt.show()
plt.savefig('../output_data/Fig2.png')


# This graph analyzes the relationship between city latitude and of humidity those places. 
# It seems that most places average a humidity percentage of 60 to 97% acros the dataset, but
# there seems to be no direct relationship of humidity to the latitude.
# So, there is not much of a realtionship

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Set x an y axis values to graph

x_axis2 = city_df['Lat']
y_axis2 = city_df['Cloudiness']

# Using matplotlib to get and save the graph

plt.scatter(x_axis2, y_axis2)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.ylim(-20, 120)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid()

plt.show()
plt.savefig('../output_data/Fig3.png')

# This graph analyzes the relationship between latitude and cloudiness. There does not seem to be much of a correlation between
# between latitude and cloudiness. However, most places tend to either have very high Cloudiness percentage or an abismal cloudiness percentaje
# So, there is not much of a realtionship

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Set x an y axis values to graph

x_axis1 = city_df['Lat']
y_axis1 = city_df['Wind Speed']

# Using matplotlib to get and save the graph

plt.scatter(x_axis1, y_axis1)
plt.title(f'City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.ylim(0, 20)
plt.xlim(-60, 80)
plt.minorticks_on()
plt.grid()

plt.show()
plt.savefig('../output_data/Fig4.png')

#This graph analyzes the relationship between latitude and wind speed. It seems that at the latitude between 
# 15 to 45, the wind speed tends to increase a bit more. Othewise,it averages pretty heavely between 1 to 3 mph. So,
# there is not much of a realtionship

# %% [markdown]
# ## Linear Regression

# %%
lat_check = city_df['Lat'] > 0

northern_h = city_df[lat_check]
southern_h = city_df[~lat_check]
northern_h
# Out:
#           ID               City      Lat       Lng  Max Temp  Humidity  \
# 0    5866583  Saint Paul Harbor  57.7900 -152.4072      7.00        81
# 1    1863997           Fukuechō  32.6881  128.8419     23.00        28
# 2    3421765         Nanortalik  60.1432  -45.2371      2.52        84
# 3    5478673        Meadow Lake  34.8014 -106.5436     13.17        25
# 5    1264976                Leh  34.1667   77.5833      5.58        46
# ..       ...                ...      ...       ...       ...       ...
# 562   108410             Riyadh  24.6877   46.7219     24.63        19
# 563  5969025    Haines Junction  60.7522 -137.5108      5.00        70
# 564  5488598            Ruidoso  33.3317 -105.6730      5.90        70
# 565  1298987           Pyinmana  19.7333   96.2167     35.00        40
# 566  1214026             Sabang   5.8933   95.3214     28.28        68
#
#      Cloudiness  Wind Speed Country                 Date
# 0            90        1.24      US  2021-04-30 04:27:21
# 1             0        6.69      JP  2021-04-30 04:27:21
# 2            11        3.59      GL  2021-04-30 04:27:22
# 3             1        3.60      US  2021-04-30 04:27:22
# 5            12        0.80      IN  2021-04-30 04:24:07
# ..          ...         ...     ...                  ...
# 562           0        2.06      SA  2021-04-30 04:31:11
# 563         100        3.09      CA  2021-04-30 04:31:12
# 564           1        2.57      US  2021-04-30 04:31:12
# 565          25        3.11      MM  2021-04-30 04:31:12
# 566         100        0.81      ID  2021-04-30 04:31:13
#
# [380 rows x 10 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Data For the plots

x_axis = northern_h['Lat']
y_axis = northern_h['Max Temp']

# Statistical values

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis , y_axis)

# linear regression model

regress_values = x_axis * slope + intercept
line_equation = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))

print(f'The r-value is: {rvalue}')

# Plot and r value

plt.scatter(x_axis, y_axis)
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.plot(x_axis, regress_values, "r-")
plt.annotate(line_equation,(5,40),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.xlim(0, 80)
plt.ylim(0, 120)
plt.show()

# This plot sets a regresion model for the maximunm temperature and latitude of the Northern Hemisphere.
# Out:
# The r-value is: -0.8872121198970078

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = southern_h['Lat']
y_axis = southern_h['Max Temp']

# Statistical values

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis , y_axis)

# linear regression model

regress_values = x_axis * slope + intercept
line_equation = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))

print(f'The r-value is: {rvalue}')

# Plot and r value

plt.scatter(x_axis, y_axis)
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.plot(x_axis, regress_values, "r-")
plt.annotate(line_equation,(-50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.xlim(0, -80)
plt.ylim(0, 120)
plt.show()

# This plot sets a regresion model for the maximunm temperature and latitude of the Southern Hemisphere.
# Out:
# The r-value is: 0.627737763733715

# %%
# The Northern and Southern Hemispheres show a inverse relationship between latitude and temperature. 
# There is a strong linear relationship for both hemishperes.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Data For the plots

x_axis = northern_h['Lat']
y_axis = northern_h['Humidity']

# Statistical values

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis , y_axis)

# linear regression model

regress_values = x_axis * slope + intercept
line_equation = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))

print(f'The r-value is: {rvalue}')

# Plot and r value

plt.scatter(x_axis, y_axis)
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.plot(x_axis, regress_values, "r-")
plt.annotate(line_equation,(0,35),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim(0, 80)
plt.ylim(0, 120)
plt.show()


# This plot sets a regresion model for the humidity percentaje and latitude of the Northern Hemisphere.
# Out:
# The r-value is: 0.14358413889993032

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = southern_h['Lat']
y_axis = southern_h['Humidity']

# Statistical values

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis , y_axis)

# linear regression model

regress_values = x_axis * slope + intercept
line_equation = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))

print(f'The r-value is: {rvalue}')

# Plot and r value

plt.scatter(x_axis, y_axis)
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.plot(x_axis, regress_values, "r-")
plt.annotate(line_equation,(-50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.xlim(10, -80)
plt.ylim(0, 120)
plt.show()

# This plot sets a regresion model for the humidity percentaje and latitude of the Southern Hemisphere.
# Out:
# The r-value is: 0.17875355977375024

# %%
# I think It can be confirmed that the humidity does not fall a trend acoording to the latitude. 
# One can confirm it just by looking at the scattered data

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Data For the plots

x_axis = northern_h['Lat']
y_axis = northern_h['Cloudiness']

# Statistical values

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis , y_axis)

# linear regression model

regress_values = x_axis * slope + intercept
line_equation = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))

print(f'The r-value is: {rvalue}')

# Plot and r value

plt.scatter(x_axis, y_axis)
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.plot(x_axis, regress_values, "r-")
plt.annotate(line_equation,(40,35),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim(0, 80)
plt.ylim(0, 120)
plt.show()

# This plot sets a regresion model for the Cloudiness percentaje and latitude of the Northern Hemisphere.
# Out:
# The r-value is: 0.10837593473841663

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = southern_h['Lat']
y_axis = southern_h['Cloudiness']

# Statistical values

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis , y_axis)

# linear regression model

regress_values = x_axis * slope + intercept
line_equation = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))

print(f'The r-value is: {rvalue}')

# Plot and r value

plt.scatter(x_axis, y_axis)
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.plot(x_axis, regress_values, "r-")
plt.annotate(line_equation,(-50,20),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.xlim(10, -80)
plt.ylim(0, 120)
plt.show()

# This plot sets a regresion model for the Cloudiness percentaje and latitude of the Southern Hemisphere.
# Out:
# The r-value is: 0.1844270129773006

# %%
# I think It can be confirmed that the cloudiness does not fall a trend acoording to the latitude either. 
# However; the information suggets that the more latitude, the more cloudiness, or at least that there are fewer clouds in the south pole.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Data For the plots

x_axis = northern_h['Lat']
y_axis = northern_h['Wind Speed']

# Statistical values

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis , y_axis)

# linear regression model

regress_values = x_axis * slope + intercept
line_equation = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))

print(f'The r-value is: {rvalue}')

# Plot and r value

plt.scatter(x_axis, y_axis)
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.plot(x_axis, regress_values, "r-")
plt.annotate(line_equation,(0,15),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlim(0, 80)
plt.ylim(0, 20)
plt.show()

# This plot sets a regresion model for the Wind Speed (mph)  and latitude of the Northern Hemisphere.
# Out:
# The r-value is: 0.25221367151879026

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = southern_h['Lat']
y_axis = southern_h['Wind Speed']

# Statistical values

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis , y_axis)

# linear regression model

regress_values = x_axis * slope + intercept
line_equation = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))

print(f'The r-value is: {rvalue}')

# Plot and r value

plt.scatter(x_axis, y_axis)
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
plt.plot(x_axis, regress_values, "r-")
plt.annotate(line_equation,(0,15),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.xlim(0, -60)
plt.ylim(0, 20)
plt.show()

# This plot sets a regresion model for the Wind Speed (mph)  and latitude of the Southern Hemisphere.
# Out:
# The r-value is: -0.34062128384571205

# %%
# The data suggests that that wind speed increases as one gets closer to the poles. The linear relationship seems strong here.
